# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/heart-failure-prediction/heart.csv

# %%
df = pd.read_csv('/kaggle/input/heart-failure-prediction/heart.csv')

# %%
df.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0

# %%
df
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %%
sns.distplot(df["Age"])
# Out:
# /tmp/ipykernel_33/2732350774.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["Age"])
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Age', ylabel='Density'>

# %%
sns.distplot(df["Age"], kde = False, hist = True, rug = True)
# Out:
# /tmp/ipykernel_33/3296013903.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["Age"], kde = False, hist = True, rug = True)
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Age'>

# %%
sns.distplot(df['Age'], bins = 10)
# Out:
# /tmp/ipykernel_33/3506567566.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Age'], bins = 10)
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Age', ylabel='Density'>

# %% [markdown]
# ## Ditribution for Numerical Columns

# %%
sns.distplot(df['RestingBP'], kde = True, color = 'blue')
# Out:
# /tmp/ipykernel_33/3747337940.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['RestingBP'], kde = True, color = 'blue')
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='RestingBP', ylabel='Density'>

# %%
sns.distplot(df['Cholesterol'], kde = True, color = 'blue')
# Out:
# /tmp/ipykernel_33/2875068687.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Cholesterol'], kde = True, color = 'blue')
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Cholesterol', ylabel='Density'>

# %%
sns.distplot(df['MaxHR'], kde = True, color = 'blue')
# Out:
# /tmp/ipykernel_33/3925814571.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['MaxHR'], kde = True, color = 'blue')
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='MaxHR', ylabel='Density'>

# %%
sns.distplot(df['Oldpeak'], kde = True, color = 'blue')
# Out:
# /tmp/ipykernel_33/3820001573.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Oldpeak'], kde = True, color = 'blue')
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Oldpeak', ylabel='Density'>

# %% [markdown]
# ## Pie Charts for Categorical

# %%
 df.groupby('Sex').size().plot(kind = 'pie', autopct = '%.2f')
# Out:
# <Axes: >

# %%
 df.groupby('ChestPainType').size().plot(kind = 'pie', autopct = '%.2f')
# Out:
# <Axes: >

# %%
 df.groupby('RestingECG').size().plot(kind = 'pie', autopct = '%.2f')
# Out:
# <Axes: >

# %%
 df.groupby('ST_Slope').size().plot(kind = 'pie', autopct = '%.2f')
# Out:
# <Axes: >

# %%
 df.groupby('HeartDisease').size().plot(kind = 'pie', autopct = '%.2f')
# Out:
# <Axes: >

# %% [markdown]
# ## Heart Disease EDA - ViolinPlot

# %%
sns.violinplot(x = df['Age'])
# Out:
# <Axes: xlabel='Age'>

# %%
sns.violinplot(y = df['Sex'], x = df["HeartDisease"])
# Out:
# <Axes: xlabel='HeartDisease', ylabel='Sex'>

# %% [markdown]
# From the above analysis we can say that more number of male are having chances of having a Heart Disease compared to female

# %%
sns.violinplot(y = df['Age'], x = df["HeartDisease"])
# Out:
# <Axes: xlabel='HeartDisease', ylabel='Age'>

# %%
sns.violinplot(y = df['Age'], x = df["HeartDisease"], hue = df['Sex'])
# Out:
# <Axes: xlabel='HeartDisease', ylabel='Age'>

# %%
sns.violinplot(y = df['RestingBP'], x = df["HeartDisease"])
# Out:
# <Axes: xlabel='HeartDisease', ylabel='RestingBP'>

# %% [markdown]
# As the both graphs are identical we can say that RestingBP doesn't play that much important role in finding out the people with Hear Disease

# %%
sns.violinplot(y = df['Cholesterol'], x = df["HeartDisease"])
# Out:
# <Axes: xlabel='HeartDisease', ylabel='Cholesterol'>

# %%
df
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %% [markdown]
# ## Heart Disease EDA - Correlation (HeatMap)

# %%
df.corr()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[83], line 1
# ----> 1 df.corr()
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/frame.py:11036, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11034 cols = data.columns
#   11035 idx = cols.copy()
# > 11036 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11038 if method == "pearson":
#   11039     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/frame.py:1981, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1979 if dtype is not None:
#    1980     dtype = np.dtype(dtype)
# -> 1981 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1982 if result.dtype is not dtype:
#    1983     result = np.array(result, dtype=dtype, copy=False)
#
# ...

# %%
type(df['Sex'][0])
# Out:
# str

# %%
df["Sex"] = df['Sex'].astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[80], line 1
# ----> 1 df["Sex"] = df['Sex'].astype(float)
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/generic.py:6640, in NDFrame.astype(self, dtype, copy, errors)
#    6634     results = [
#    6635         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6636     ]
#    6638 else:
#    6639     # else, only a single dtype is given
# -> 6640     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6641     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6642     return res.__finalize__(self, method="astype")
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/internals/managers.py:430, in BaseBlockManager.astype(self, dtype, copy, errors)
#     427 elif using_copy_on_write():
#     428     copy = False
# --> 430 return self.apply(
# ...

# %% [markdown]
# If the below Cell is runned it changes the String value to Float but at the cost of replacing it with NaN value and the the whole dataframe is getting filled with nan values

# %%
df['Sex'] = pd.to_numeric(df['Sex'],errors='coerce')
df['RestingECG'] = pd.to_numeric(df['RestingECG'],errors='coerce')
df['ExerciseAngina'] = pd.to_numeric(df['ExerciseAngina'],errors='coerce')
df['ChestPainType'] = pd.to_numeric(df['ChestPainType'],errors='coerce')
df['ST_Slope'] = pd.to_numeric(df['ST_Slope'],errors='coerce')
# By setting errors=’coerce’, you’ll transform the non-numeric values into NaN.

# %%
df.apply(lambda row: row.astype(str).str.contains('TEST').any(), axis=1)
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 913    False
# 914    False
# 915    False
# 916    False
# 917    False
# Length: 918, dtype: bool

# %%
df['Sex'] = pd.to_numeric(df['Sex'],errors='ignore')
# Out:
# /tmp/ipykernel_33/1016304310.py:1: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   df['Sex'] = pd.to_numeric(df['Sex'],errors='ignore')
# /tmp/ipykernel_33/1016304310.py:2: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   df['RestingECG'] = pd.to_numeric(df['RestingECG'],errors='ignore')
# /tmp/ipykernel_33/1016304310.py:3: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   df['ExerciseAngina'] = pd.to_numeric(df['ExerciseAngina'],errors='ignore')
# /tmp/ipykernel_33/1016304310.py:4: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
# ...

# %%
df['RestingECG'] = pd.to_numeric(df['RestingECG'],errors='ignore')
# Out:
# /tmp/ipykernel_33/2058811765.py:1: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   df['RestingECG'] = pd.to_numeric(df['RestingECG'],errors='ignore')

# %%
df['ExerciseAngina'] = pd.to_numeric(df['ExerciseAngina'],errors='ignore')
# Out:
# /tmp/ipykernel_33/1893896953.py:1: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   df['ExerciseAngina'] = pd.to_numeric(df['ExerciseAngina'],errors='ignore')

# %%
df['ChestPainType'] = pd.to_numeric(df['ChestPainType'],errors='ignore')
# Out:
# /tmp/ipykernel_33/1976956278.py:1: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   df['ChestPainType'] = pd.to_numeric(df['ChestPainType'],errors='ignore')

# %%
df['ST_Slope'] = pd.to_numeric(df['ST_Slope'],errors='ignore')
# Out:
# /tmp/ipykernel_33/84711374.py:1: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   df['ST_Slope'] = pd.to_numeric(df['ST_Slope'],errors='ignore')

# %%
df.corr()
# Out:
#                      Age  Sex  ChestPainType  RestingBP  Cholesterol  \
# Age             1.000000  NaN            NaN   0.254399    -0.095282
# Sex                  NaN  NaN            NaN        NaN          NaN
# ChestPainType        NaN  NaN            NaN        NaN          NaN
# RestingBP       0.254399  NaN            NaN   1.000000     0.100893
# Cholesterol    -0.095282  NaN            NaN   0.100893     1.000000
# FastingBS       0.198039  NaN            NaN   0.070193    -0.260974
# RestingECG           NaN  NaN            NaN        NaN          NaN
# MaxHR          -0.382045  NaN            NaN  -0.112135     0.235792
# ExerciseAngina       NaN  NaN            NaN        NaN          NaN
# Oldpeak         0.258612  NaN            NaN   0.164803     0.050148
# ST_Slope             NaN  NaN            NaN        NaN          NaN
# HeartDisease    0.282039  NaN            NaN   0.107589    -0.232741
#
# ...

# %%
df.isna().sum()
# Out:
# Age                 0
# Sex               918
# ChestPainType     918
# RestingBP           0
# Cholesterol         0
# FastingBS           0
# RestingECG        918
# MaxHR               0
# ExerciseAngina    918
# Oldpeak             0
# ST_Slope          918
# HeartDisease        0
# dtype: int64

# %%
df.head()
# Out:
#    Age  Sex  ChestPainType  RestingBP  Cholesterol  FastingBS  RestingECG  \
# 0   40  NaN            NaN        140          289          0         NaN
# 1   49  NaN            NaN        160          180          0         NaN
# 2   37  NaN            NaN        130          283          0         NaN
# 3   48  NaN            NaN        138          214          0         NaN
# 4   54  NaN            NaN        150          195          0         NaN
#
#    MaxHR  ExerciseAngina  Oldpeak  ST_Slope  HeartDisease
# 0    172             NaN      0.0       NaN             0
# 1    156             NaN      1.0       NaN             1
# 2     98             NaN      0.0       NaN             0
# 3    108             NaN      1.5       NaN             1
# 4    122             NaN      0.0       NaN             0

# %%
sns.heatmap(df.corr())
# Out:
# <Axes: >

# %% [markdown]
# ## Heart Disease EDA - Correlation - (JointPlot)

# %%
sns.jointplot(x = "Age", y = 'MaxHR', data = df)
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.jointplot(x = "Age", y = 'MaxHR', data = df, kind = 'hex')
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# The line on the jointplot shows the line which hels us in finding correlation between 2 things

# %%
sns.jointplot(x = "Age", y = 'Age', data = df)
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.jointplot(x = "HeartDisease", y = 'Oldpeak', data = df)
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# The above plot shows 0 correlation between the 2 things

# %%
sns.jointplot(x = "Cholesterol", y = 'MaxHR', data = df)
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.jointplot(x = "Age", y = 'MaxHR', data = df, kind = 'reg')
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
df.head()
# Out:
#    Age  Sex  ChestPainType  RestingBP  Cholesterol  FastingBS  RestingECG  \
# 0   40  NaN            NaN        140          289          0         NaN
# 1   49  NaN            NaN        160          180          0         NaN
# 2   37  NaN            NaN        130          283          0         NaN
# 3   48  NaN            NaN        138          214          0         NaN
# 4   54  NaN            NaN        150          195          0         NaN
#
#    MaxHR  ExerciseAngina  Oldpeak  ST_Slope  HeartDisease
# 0    172             NaN      0.0       NaN             0
# 1    156             NaN      1.0       NaN             1
# 2     98             NaN      0.0       NaN             0
# 3    108             NaN      1.5       NaN             1
# 4    122             NaN      0.0       NaN             0

# %%
sns.jointplot(x = "Cholesterol", y = 'FastingBS', data = df, kind = 'reg')
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# THe regression line is not fitting properly with the data so there is no correlation

# %%
sns.jointplot(x = "HeartDisease", y = 'MaxHR', data = df, kind = 'reg')
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ## Heart Disease EDA - Corrlation (PairPlot)

# %%
sns.pairplot(df)
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...
